# %%
import pandas as pd

# %%
#Reading the Iris Dataset into a dataframe 
data = pd.read_csv('C:/Users/anush/NEU_resources_and_projects/DMT/iris_csv.csv')

# %%
data
# Out:
#      sepallength  sepalwidth  petallength  petalwidth           class
# 0            5.1         3.5          1.4         0.2     Iris-setosa
# 1            4.9         3.0          1.4         0.2     Iris-setosa
# 2            4.7         3.2          1.3         0.2     Iris-setosa
# 3            4.6         3.1          1.5         0.2     Iris-setosa
# 4            5.0         3.6          1.4         0.2     Iris-setosa
# ..           ...         ...          ...         ...             ...
# 145          6.7         3.0          5.2         2.3  Iris-virginica
# 146          6.3         2.5          5.0         1.9  Iris-virginica
# 147          6.5         3.0          5.2         2.0  Iris-virginica
# 148          6.2         3.4          5.4         2.3  Iris-virginica
# 149          5.9         3.0          5.1         1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# # Question 1.1

# %%
datadf = pd.DataFrame(data.describe())

# %%
datadf = datadf.T

# %%
datadf['range'] = datadf['max'] - datadf['min']

# %%
datadf
# Out:
#              count      mean       std  min  25%   50%  75%  max  range
# sepallength  150.0  5.843333  0.828066  4.3  5.1  5.80  6.4  7.9    3.6
# sepalwidth   150.0  3.054000  0.433594  2.0  2.8  3.00  3.3  4.4    2.4
# petallength  150.0  3.758667  1.764420  1.0  1.6  4.35  5.1  6.9    5.9
# petalwidth   150.0  1.198667  0.763161  0.1  0.3  1.30  1.8  2.5    2.4

# %%
datadfFinal = datadf.T
datadfFinal
# Out:
#        sepallength  sepalwidth  petallength  petalwidth
# count   150.000000  150.000000   150.000000  150.000000
# mean      5.843333    3.054000     3.758667    1.198667
# std       0.828066    0.433594     1.764420    0.763161
# min       4.300000    2.000000     1.000000    0.100000
# 25%       5.100000    2.800000     1.600000    0.300000
# 50%       5.800000    3.000000     4.350000    1.300000
# 75%       6.400000    3.300000     5.100000    1.800000
# max       7.900000    4.400000     6.900000    2.500000
# range     3.600000    2.400000     5.900000    2.400000

# %% [markdown]
# # Question 1.2 (Histograms, Boxplot, Pairwise Plot and Histogram by Class)

# %%
pdhist = data.hist(figsize=(20,10))

# %%
boxplt = data.boxplot(grid = False, return_type = 'axes')

# %%
import seaborn as sb
pairplt = sb.pairplot(data)

# %%
classes = pd.DataFrame(data['class'].unique(), columns =  {'class'})
classes
# Out:
#              class
# 0      Iris-setosa
# 1  Iris-versicolor
# 2   Iris-virginica

# %%
grouped = data.groupby('class')
setosa = grouped.get_group('Iris-setosa')
setosaHist = setosa.hist(figsize=(20,10))

# %%
versicolor = grouped.get_group('Iris-versicolor')
versicolorHist = versicolor.hist(figsize=(20,10))

# %%
virginica = grouped.get_group('Iris-virginica')
virginicaHist = virginica.hist(figsize=(20,10))

# %% [markdown]
# # 1.3 Conceptual Questions

# %% [markdown]
# #### 1. There are 4 feautres in the iris dataset. sepallength, sepalwidth, petallength, petalwidth are all of numeric type.

# %% [markdown]
# #### 2. From the histogram we can observe that for petallength and petalwidth the values are concentrated on the borders. For sepallength and sepalwidth the values are concentrated in the middle.
#
# #### We can clearly see from the petallength histogram that some of the values are missing. Missing values range from 2.2 to 2.8. Due to this distribution in this range is 0.  Because of this we can segemen the petal length values into 2 parts. One part ranging from (1.0,2.2) and the other ranging from (2.8,6.9)

# %% [markdown]
# #### 3. Most significant difference in medians can be seen in sepallength and petallength.
# #### The most amount of data can be dervied from petallength. This is because the distribution is the largest here.

# %% [markdown]
# #### 4. sepalength vs petallength
# ####     sepallength vs petalwidth
# ####     petallength vs petalwidth

# %% [markdown]
# #### 5.
# ####     petallength of whole dataset to petallength classes:
# ####     For the whole dataset and setosa class petal length is moderately distributed. While for virginica and versicolor it is densely distributed.
# ####     petalwidth of whole dataset to petalwidth classes:
# ####     For the whole dataset and Iris-versicolor, petal width is moderately distributed, whereas for Iris-setosa, it is sparsely distributed and for Iris-virginica, it is densely distributed.
# ####    sepalwidth of whole dataset to sepalwidth for classes:
# ####    For Iris-setosa, sepal width is moderately distributed, when compared to Iris-virginica, which is sparsely distributed, and to Iris-versicolor which has a dense distribution.
# ####   Sepal length of whole dataset to sepal length for classes:
# ####   Iris-setosa sepal widths are moderately distributed in the dataset, whereas iris-virginica and iris-versicolor sepal widths are densely distributed.

# %%
#--------------------------------------------------QUESTION 2---------------------------------------------------------

# %%
dataAir = pd.read_excel('C:/Users/anush/NEU_resources_and_projects/DMT/AirQualityUCI/AirQualityUCI.xlsx')

# %%
dataAir
# Out:
#            Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)   C6H6(GT)  \
# 0    2004-03-10  18:00:00     2.6      1360.00       150  11.881723
# 1    2004-03-10  19:00:00     2.0      1292.25       112   9.397165
# 2    2004-03-10  20:00:00     2.2      1402.00        88   8.997817
# 3    2004-03-10  21:00:00     2.2      1375.50        80   9.228796
# 4    2004-03-10  22:00:00     1.6      1272.25        51   6.518224
# ...         ...       ...     ...          ...       ...        ...
# 9352 2005-04-04  10:00:00     3.1      1314.25      -200  13.529605
# 9353 2005-04-04  11:00:00     2.4      1162.50      -200  11.355157
# 9354 2005-04-04  12:00:00     2.4      1142.00      -200  12.374538
# 9355 2005-04-04  13:00:00     2.1      1002.50      -200   9.547187
# 9356 2005-04-04  14:00:00     2.2      1070.75      -200  11.932060
#
#       PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  \
# 0           1045.50    166.0       1056.25    113.0       1692.00
# ...

# %% [markdown]
# ## 2.1

# %%
pd.DataFrame(dataAir.describe())
# Out:
#             CO(GT)  PT08.S1(CO)     NMHC(GT)     C6H6(GT)  PT08.S2(NMHC)  \
# count  9357.000000  9357.000000  9357.000000  9357.000000    9357.000000
# mean    -34.207524  1048.869652  -159.090093     1.865576     894.475963
# std      77.657170   329.817015   139.789093    41.380154     342.315902
# min    -200.000000  -200.000000  -200.000000  -200.000000    -200.000000
# 25%       0.600000   921.000000  -200.000000     4.004958     711.000000
# 50%       1.500000  1052.500000  -200.000000     7.886653     894.500000
# 75%       2.600000  1221.250000  -200.000000    13.636091    1104.750000
# max      11.900000  2039.750000  1189.000000    63.741476    2214.000000
#
#            NOx(GT)  PT08.S3(NOx)      NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)  \
# count  9357.000000   9357.000000  9357.000000   9357.000000  9357.000000
# mean    168.604200    794.872333    58.135898   1391.363266   974.951534
# std     257.424561    321.977031   126.931428    467.192382   456.922728
# ...

# %%
airHist = dataAir.hist(figsize=(20,20), xrot = 45)

# %%
airBox = dataAir.boxplot(grid=False, showfliers=False, rot=45)

# %% [markdown]
# #### 2.3
# #### 1. Negative values are considered abnormalities .This is because the dataframe has values that are concentrations. Such values can not be below zero. For example we can see in column NMHC(GT) rows 9352 - 9356 the values are negative. Similarly there are other values that have these negative values.
#
# #### 2. From the sumary table we can see that min row has all negative values. This is considered an abnormality because the units are of concentration and can not be negative.
#
# #### 3. The natural way to deal with negative values that are considered abnormalities are by replacing negative values by 0 and removing them. It is done in the below code block.
#
# #### 4. Histogram after removing negative values shown in the end

# %%
dataAir.drop(dataAir.columns[[0,1]], axis=1, inplace=True)

# %%
dataAir
# Out:
#       CO(GT)  PT08.S1(CO)  NMHC(GT)   C6H6(GT)  PT08.S2(NMHC)  NOx(GT)  \
# 0        2.6      1360.00       150  11.881723        1045.50    166.0
# 1        2.0      1292.25       112   9.397165         954.75    103.0
# 2        2.2      1402.00        88   8.997817         939.25    131.0
# 3        2.2      1375.50        80   9.228796         948.25    172.0
# 4        1.6      1272.25        51   6.518224         835.50    131.0
# ...      ...          ...       ...        ...            ...      ...
# 9352     3.1      1314.25      -200  13.529605        1101.25    471.7
# 9353     2.4      1162.50      -200  11.355157        1027.00    353.3
# 9354     2.4      1142.00      -200  12.374538        1062.50    293.0
# 9355     2.1      1002.50      -200   9.547187         960.50    234.5
# 9356     2.2      1070.75      -200  11.932060        1047.25    265.2
#
#       PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)       T         RH  \
# ...

# %%
dataAir1 = dataAir.clip(lower=0)

# %%
dataAir1
# Out:
#       CO(GT)  PT08.S1(CO)  NMHC(GT)   C6H6(GT)  PT08.S2(NMHC)  NOx(GT)  \
# 0        2.6      1360.00       150  11.881723        1045.50    166.0
# 1        2.0      1292.25       112   9.397165         954.75    103.0
# 2        2.2      1402.00        88   8.997817         939.25    131.0
# 3        2.2      1375.50        80   9.228796         948.25    172.0
# 4        1.6      1272.25        51   6.518224         835.50    131.0
# ...      ...          ...       ...        ...            ...      ...
# 9352     3.1      1314.25         0  13.529605        1101.25    471.7
# 9353     2.4      1162.50         0  11.355157        1027.00    353.3
# 9354     2.4      1142.00         0  12.374538        1062.50    293.0
# 9355     2.1      1002.50         0   9.547187         960.50    234.5
# 9356     2.2      1070.75         0  11.932060        1047.25    265.2
#
#       PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)       T         RH  \
# ...

# %%
airHist1 = dataAir1.hist(figsize=(20,20), xrot = 45)
airHist1
# Out:
# array([[<AxesSubplot:title={'center':'CO(GT)'}>,
#         <AxesSubplot:title={'center':'PT08.S1(CO)'}>,
#         <AxesSubplot:title={'center':'NMHC(GT)'}>,
#         <AxesSubplot:title={'center':'C6H6(GT)'}>],
#        [<AxesSubplot:title={'center':'PT08.S2(NMHC)'}>,
#         <AxesSubplot:title={'center':'NOx(GT)'}>,
#         <AxesSubplot:title={'center':'PT08.S3(NOx)'}>,
#         <AxesSubplot:title={'center':'NO2(GT)'}>],
#        [<AxesSubplot:title={'center':'PT08.S4(NO2)'}>,
#         <AxesSubplot:title={'center':'PT08.S5(O3)'}>,
#         <AxesSubplot:title={'center':'T'}>,
#         <AxesSubplot:title={'center':'RH'}>],
#        [<AxesSubplot:title={'center':'AH'}>, <AxesSubplot:>,
#         <AxesSubplot:>, <AxesSubplot:>]], dtype=object)
